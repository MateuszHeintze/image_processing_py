# %% [markdown]
# <a href="https://colab.research.google.com/github/intertech-academy/image_processing_py/blob/main/CPO2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Przetwarzanie obrazów barwnych

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import skimage.color

# %%
im = np.array(Image.open('delivery.jpg'))

plt.imshow(im)

# %%
plt.imshow(im[:, :, 0])

plt.title('Czerwony')
plt.colorbar()
plt.clim(0, 255)

# %%
plt.imshow(im[:, :, 1])

plt.title('Zielony')
plt.colorbar()
plt.clim(0, 255)

# %%
plt.imshow(im[:, :, 2])

plt.title('Niebieski')
plt.colorbar()
plt.clim(0, 255)

# %% [markdown]
# ## Reprezentacja HSV
#
# H - hue (odcień)
# S - saturation (nasycenie)
# V - value (wartość/jasność)

# %%
im_hsv = skimage.color.rgb2hsv(im)

im_hsv.shape
#plt.imshow(im_hsv)
# Out:
# (341, 512, 3)

# %%
plt.imshow(im_hsv[:, :, 0])

plt.title('Hue (odcien)')
plt.colorbar()
plt.clim(0, 1)

# %%
plt.imshow(im_hsv[:, :, 1])

plt.title('Saturation (nasycenie)')
plt.colorbar()
plt.clim(0, 1)

# %%
plt.imshow(im_hsv[:, :, 2], cmap='gray')

plt.title('Value (jasnosc)')
plt.colorbar()
plt.clim(0, 1)

# %% [markdown]
# ## Modyfikacja składowych HSV

# %%
im_hsv2 = im_hsv.copy()
im_hsv2[:,:,1] = im_hsv2[:,:,1]*1.5

im2 = skimage.color.hsv2rgb(im_hsv2)

plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.imshow(im)

plt.subplot(1,2,2)
plt.imshow(im2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im_hsv3 = im_hsv.copy()
im_hsv3[:,:,2] = im_hsv3[:,:,2]*1.5

im3 = skimage.color.hsv2rgb(im_hsv3)

plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.imshow(im)

plt.subplot(1,2,2)
plt.imshow(im3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im_hsv4 = im_hsv.copy()
im_hsv4[:,:,0] = im_hsv4[:,:,0]+0.1

im4 = skimage.color.hsv2rgb(im_hsv4)

plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.imshow(im)

plt.subplot(1,2,2)
plt.imshow(im4)

# %% [markdown]
# ## Zmiana koloru ubrania

# %%
mask = np.logical_and(im_hsv[:,:,0] > 0.2, im_hsv[:,:,0] < 0.8) 

plt.imshow(mask)
plt.colorbar()

# %%
ind = np.argwhere(mask == 1)
ind.shape
# Out:
# (24306, 2)

# %%
rows = ind[:, 0]
cols = ind[:, 1]

im_hsv5 = im_hsv.copy()
im_hsv5[rows, cols, 0] = im_hsv5[rows, cols, 0]+0.1

im5 = skimage.color.hsv2rgb(im_hsv5)

plt.figure(figsize=(16,8))

plt.subplot(1,2,1)
plt.imshow(im)

plt.subplot(1,2,2)
plt.imshow(im5)
